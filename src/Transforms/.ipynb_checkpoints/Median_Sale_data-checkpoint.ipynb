# %%
import pandas as pd
import numpy as np

zip_median_load = "Sale_Prices_Zip.csv"

sale_price = pd.read_csv(zip_median_load)
sale_price.head()
# Out:
#    RegionID  RegionName StateName  SizeRank  2008-03  2008-04  2008-05  \
# 0     61639       10025  New York         1      NaN      NaN      NaN
# 1     84654       60657  Illinois         2      NaN      NaN      NaN
# 2     61637       10023  New York         3      NaN      NaN      NaN
# 3     91982       77494     Texas         4      NaN      NaN      NaN
# 4     84616       60614  Illinois         5      NaN      NaN      NaN
#
#    2008-06  2008-07  2008-08  ...  2018-11  2018-12  2019-01    2019-02  \
# 0      NaN      NaN      NaN  ...  1042600   943300   938300   926700.0
# 1      NaN      NaN      NaN  ...   386200   410600   436400   447400.0
# 2      NaN      NaN      NaN  ...   963900  1072000  1124700  1268000.0
# 3      NaN      NaN      NaN  ...   310500   328000   333100   344800.0
# 4      NaN      NaN      NaN  ...   505000   524300   520600   550900.0
#
#      2019-03    2019-04    2019-05    2019-06    2019-07    2019-08
# ...

# %%
sale_price1 = sale_price.rename(columns={'RegionName':'zip_code'})

# %%
va_sale_price = sale_price1.loc[sale_price['StateName'] == "Virginia"]
va_sale_price
# Out:
#       RegionID  zip_code StateName  SizeRank   2008-03   2008-04   2008-05  \
# 41       67732     23464  Virginia        42       NaN       NaN       NaN
# 47       67730     23462  Virginia        48       NaN       NaN       NaN
# 148      67180     22191  Virginia       149       NaN       NaN       NaN
# 150      67655     23320  Virginia       151  243600.0  229500.0  225200.0
# 191      67222     22304  Virginia       192       NaN       NaN       NaN
# 199      67722     23454  Virginia       200  254500.0  251500.0  256600.0
# 202      67182     22193  Virginia       203       NaN       NaN       NaN
# 205      67787     23666  Virginia       206  186800.0  192300.0  181000.0
# 213      66242     20147  Virginia       214       NaN       NaN       NaN
# 231      67598     23223  Virginia       232       NaN       NaN       NaN
# 248      67720     23452  Virginia       249  218200.0  213400.0  211100.0
# ...

# %%
va_2018_price = va_sale_price[['zip_code','StateName', '2018-01', '2018-02','2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12']]
va_2018_price.head()
# Out:
#      zip_code StateName  2018-01  2018-02  2018-03  2018-04  2018-05  2018-06  \
# 41      23464  Virginia   232500   231700   241100   249900   254000   249600
# 47      23462  Virginia   187700   199000   201400   198600   184400   185200
# 148     22191  Virginia   304100   317800   316100   308300   310700   310100
# 150     23320  Virginia   217500   231100   232900   242300   241500   240500
# 191     22304  Virginia   318000   318300   318100   332200   323200   328800
#
#      2018-07  2018-08  2018-09  2018-10  2018-11  2018-12
# 41    239700   236600   242300   247000   249200   241900
# 47    184900   189700   190600   186500   188800   188100
# 148   308900   299000   309400   316600   317300   316100
# 150   234400   227400   224900   224100   235200   246600
# 191   329900   327700   324800   305500   308900   307600

# %%
sale_zip_final_price = va_2018_price[['2018-01', '2018-02','2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12']].mean(axis=1)
sale_zip_final_price
# Out:
# 41      242958.333333
# 47      190408.333333
# 148     311200.000000
# 150     233200.000000
# 191     320250.000000
# 199     275033.333333
# 202     310633.333333
# 205     164533.333333
# 213     446925.000000
# 231     149983.333333
# 248     230116.666667
# 265     379525.000000
# 297     424616.666667
# 373     334950.000000
# 403     273150.000000
# 424     260391.666667
# 452     330850.000000
# 454     554966.666667
# 480     250350.000000
# 484     325325.000000
# 488     280541.666667
# 504     208533.333333
# 508     540583.333333
# 559     510341.666667
# 582     294008.333333
# 587     344275.000000
# 596     305533.333333
# 623     200216.666667
# 646     645666.666667
# 697     559483.333333
#             ...
# 4857    434875.000000
# 4870    779141.666667
# 4893    237775.000000
# 4897    306733.333333
# 4909    261666.666667
# 4935    492733.333333
# 4982    353291.666667
# 4987    181200.000000
# 5031    481533.333333
# 5037    168341.666667
# ...

# %%
va_2018_price = va_2018_price.assign(sale_zip_final_price=sale_zip_final_price.values)
va_2018_price
# Out:
#       zip_code StateName  2018-01  2018-02  2018-03  2018-04  2018-05  \
# 41       23464  Virginia   232500   231700   241100   249900   254000
# 47       23462  Virginia   187700   199000   201400   198600   184400
# 148      22191  Virginia   304100   317800   316100   308300   310700
# 150      23320  Virginia   217500   231100   232900   242300   241500
# 191      22304  Virginia   318000   318300   318100   332200   323200
# 199      23454  Virginia   261900   269500   291600   287700   286100
# 202      22193  Virginia   311200   307300   307300   311400   312100
# 205      23666  Virginia   166500   164600   160800   160400   166100
# 213      20147  Virginia   438900   449200   456000   446200   447000
# 231      23223  Virginia   151200   152800   157300   157700   153700
# 248      23452  Virginia   226600   228800   223900   227600   231000
# 265      23451  Virginia   390700   376400   379900   364300   375600
# ...

# %%
final =  va_2018_price[['zip_code','StateName','sale_zip_final_price']]
final1 = final.rename(columns={'sale_zip_final_price': '2018_median_sale_price','StateName':'state_name'})
final2 = final1.round(2)
final2
# Out:
#       zip_code state_name  2018_median_sale_price
# 41       23464   Virginia               242958.33
# 47       23462   Virginia               190408.33
# 148      22191   Virginia               311200.00
# 150      23320   Virginia               233200.00
# 191      22304   Virginia               320250.00
# 199      23454   Virginia               275033.33
# 202      22193   Virginia               310633.33
# 205      23666   Virginia               164533.33
# 213      20147   Virginia               446925.00
# 231      23223   Virginia               149983.33
# 248      23452   Virginia               230116.67
# 265      23451   Virginia               379525.00
# 297      22204   Virginia               424616.67
# 373      23322   Virginia               334950.00
# 403      23455   Virginia               273150.00
# 424      22407   Virginia               260391.67
# 452      22192   Virginia               330850.00
# 454      22201   Virginia               554966.67
# ...

# %%
# final2.to_csv(index=False)
